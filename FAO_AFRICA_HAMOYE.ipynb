# %% [markdown]
# <a href="https://colab.research.google.com/github/lisa-nga/HDSC-Introduction-to-Python-for-machine-learning/blob/master/FAO_AFRICA_HAMOYE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url='https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv'

# %%
fao= pd.read_csv(url,encoding='latin-1')

# %% [markdown]
# # New Section

# %%
fao.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
fao.describe(include='all')
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %%
fao.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
fao.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
fao.fillna(0)
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
fao.groupby('Area').sum()
# Out:
#                              Area Code  Item Code  Element Code       Y2014  \
# Area
# Algeria                           5252    3532053       5017927   313375.33
# Angola                            9968    3819908       5515088   208584.42
# Benin                            68105    3453692       4852820   118050.79
# Botswana                         27560    3704902       5259784    22339.92
# Burkina Faso                    328297    3778795       5431243   105051.33
# Cabo Verde                       44100    3396746       4787751    14576.94
# Cameroon                         46720    3916078       5663196   217630.28
# Central African Republic         49728    3607546       5069094    28739.02
# Chad                             52377    3606529       5108355    65940.17
# Comoros                           2025     124514        241681       32.00
# Congo                            64998    3792029       5445560    38699.26
# ...

# %%
fao.groupby('Area').count()
# Out:
#                              Area Code  Item Code  Item  Element Code  \
# Area
# Algeria                           1313       1313  1313          1313
# Angola                            1424       1424  1424          1424
# Benin                             1285       1285  1285          1285
# Botswana                          1378       1378  1378          1378
# Burkina Faso                      1409       1409  1409          1409
# Cabo Verde                        1260       1260  1260          1260
# Cameroon                          1460       1460  1460          1460
# Central African Republic          1344       1344  1344          1344
# Chad                              1343       1343  1343          1343
# Comoros                             45         45    45            45
# Congo                             1413       1413  1413          1413
# Côte d'Ivoire                     1467       1467  1467          1467
# ...

# %%
fao.groupby('Area')['Y2014'].count()
# Out:
# Area
# Algeria                        1261
# Angola                         1378
# Benin                          1250
# Botswana                       1361
# Burkina Faso                   1382
# Cabo Verde                     1231
# Cameroon                       1450
# Central African Republic       1300
# Chad                           1284
# Comoros                          45
# Congo                          1382
# Côte d'Ivoire                  1444
# Djibouti                       1052
# Egypt                          1461
# Eswatini                       1265
# Ethiopia                       1424
# Ethiopia PDR                     39
# Gabon                          1200
# Gambia                         1121
# Ghana                          1337
# Guinea                         1345
# Guinea-Bissau                  1044
# Kenya                          1544
# Lesotho                        1130
# Liberia                        1135
# Madagascar                     1416
# ...

# %%
fao.groupby('Item')['Y2014','Y2015','Y2016','Y2017','Y2018'].count()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                      Y2014  Y2015  Y2016  Y2017  Y2018
# Item
# Alcohol, Non-Food      275    271    274    273    273
# Alcoholic Beverages    562    559    559    560    561
# Animal Products        135    135    135    135    135
# Animal fats            635    633    633    636    636
# Apples and products    510    511    512    511    508
# ...                    ...    ...    ...    ...    ...
# Vegetables, Other      575    573    577    574    576
# Vegetal Products       135    135    135    135    135
# Wheat and products     645    648    645    646    647
# Wine                   491    490    493    491    487
# Yams                   318    330    333    349    336
#
# [119 rows x 5 columns]

# %%
fao.groupby('Item')['Y2014','Y2017'].sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                          Y2014      Y2017
# Item
# Alcohol, Non-Food      2403.00    2348.00
# Alcoholic Beverages  102410.11   95581.06
# Animal Products       11935.65   11547.65
# Animal fats          209460.54  269617.53
# Apples and products    9499.23   10198.90
# ...                        ...        ...
# Vegetables, Other    155038.96  157752.59
# Vegetal Products     107145.19  107655.20
# Wheat and products   232670.13  240047.62
# Wine                   4497.36    4178.02
# Yams                 200396.96  229174.59
#
# [119 rows x 2 columns]

# %%
fao.groupby('Element')['Y2018','Area'].sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                              Y2018
# Element
# Domestic supply quantity                2161192.10
# Export Quantity                          181594.80
# Fat supply quantity (g/capita/day)        10258.69
# Feed                                     233489.68
# Food                                    1303841.28
# Food supply (kcal/capita/day)            455261.00
# Food supply quantity (kg/capita/yr)       49056.85
# Import Quantity                          287997.09
# Losses                                   163902.00
# Other uses (non-food)                     91300.97
# Processing                               308429.00
# Production                              2075072.89
# Protein supply quantity (g/capita/day)    11833.56
# ...

# %%
plt.figure(figsize=(7,4))

# %%
fao.dropna()
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
fao.groupby('Element')['Y2018'].sum()
# Out:
# Element
# Domestic supply quantity                  2161192.10
# Export Quantity                            181594.80
# Fat supply quantity (g/capita/day)          10258.69
# Feed                                       233489.68
# Food                                      1303841.28
# Food supply (kcal/capita/day)              455261.00
# Food supply quantity (kg/capita/yr)         49056.85
# Import Quantity                            287997.09
# Losses                                     163902.00
# Other uses (non-food)                       91300.97
# Processing                                 308429.00
# Production                                2075072.89
# Protein supply quantity (g/capita/day)      11833.56
# Residuals                                   34864.00
# Seed                                        25263.14
# Stock Variation                             20577.91
# Total Population - Both sexes             1140605.00
# Tourist consumption                            90.00
# ...

# %%
fao.groupby('Element')['Y2014','Y2015','Y2016','Y2017','Y2018'].sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# Import Quantity                          274144.48   267018.46   286582.78
# ...

# %%
fao.groupby('Element')['Y2014'].sum()
# Out:
# Element
# Domestic supply quantity                  1996716.35
# Export Quantity                            150020.64
# Fat supply quantity (g/capita/day)          10225.56
# Feed                                       216927.89
# Food                                      1212332.49
# Food supply (kcal/capita/day)              454257.00
# Food supply quantity (kg/capita/yr)         49650.63
# Import Quantity                            274144.48
# Losses                                     153223.00
# Other uses (non-food)                       78718.13
# Processing                                 282923.00
# Production                                1931287.75
# Protein supply quantity (g/capita/day)      11836.46
# Residuals                                   30149.00
# Seed                                        21922.92
# Stock Variation                             58749.83
# Total Population - Both sexes             1031585.00
# Tourist consumption                           416.00
# ...

# %%
fao.groupby('Area')['Y2018'].sum()
# Out:
# Area
# Algeria                         341729.98
# Angola                          235206.68
# Benin                           124960.70
# Botswana                         23129.08
# Burkina Faso                    112970.72
# Cabo Verde                       14622.60
# Cameroon                        233022.93
# Central African Republic         30101.57
# Chad                             72282.24
# Comoros                             59.84
# Congo                            42005.53
# Côte d'Ivoire                   227018.00
# Djibouti                         23718.96
# Egypt                           852652.92
# Eswatini                         55045.07
# Ethiopia                        450788.86
# Ethiopia PDR                         0.00
# Gabon                            28339.38
# Gambia                           23513.80
# Ghana                           358915.64
# Guinea                          103262.08
# Guinea-Bissau                    18997.92
# ...

# %%
S = [['him', 'sell'], [90, 28, 43]]
S[0][1][1]
# Out:
# 'e'
